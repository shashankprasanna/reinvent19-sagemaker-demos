# %% [markdown]
# # Direct Marketing with XGBoost and Amazon SageMaker
# Featuring SageMaker AutoPilot, SageMaker Processing, SageMaker Experiments, and SageMaker Model Monitoring

# %%
# !pip install sagemaker smdebug --upgrade

# %%
# !pip install botocore --upgrade
# !pip install boto3 --upgrade

# %%
import botocore
botocore.__version__
region
# Out:
# 'us-west-2'

# %%
import boto3
import sagemaker
import os, sys

print (sagemaker.__version__)

sess   = sagemaker.Session()
bucket = sess.default_bucket()                     
prefix = 'sagemaker/DEMO-automl-dm'
region = boto3.Session().region_name

# Role when working on a notebook instance
role = sagemaker.get_execution_role()
# Out:
# 1.45.1

# %%
sm = boto3.Session().client(service_name='sagemaker',region_name=region)
sm_rt = boto3.Session().client('runtime.sagemaker', region_name=region)

# %%
import numpy as np 
import pandas as pd

# %%
# !wget -N https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# !unzip -o bank-additional.zip
# Out:
# --2019-12-09 04:32:55--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 444572 (434K) [application/x-httpd-php]
# Saving to: ‘bank-additional.zip’
#
# bank-additional.zip 100%[===================>] 434.15K  2.43MB/s    in 0.2s
#
# 2019-12-09 04:32:56 (2.43 MB/s) - ‘bank-additional.zip’ saved [444572/444572]
#
# Archive:  bank-additional.zip
#    creating: bank-additional/
#   inflating: bank-additional/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/bank-additional/
#   inflating: __MACOSX/bank-additional/._.DS_Store
#   inflating: bank-additional/.Rhistory
#   inflating: bank-additional/bank-additional-full.csv
#   inflating: bank-additional/bank-additional-names.txt
#   inflating: bank-additional/bank-additional.csv
#   inflating: __MACOSX/._bank-additional

# %% [markdown]
# Let's read the CSV file into a Pandas data frame and take a look at the first few lines.

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
data = pd.read_csv('./bank-additional/bank-additional-full.csv', sep=';')
pd.set_option('display.max_columns', 500)     # Make sure we can see all of the columns
pd.set_option('display.max_rows', 50)         # Keep the output on one page
data[:10] # Show the first 10 lines
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  duration  campaign  pdays  previous  \
# 0  telephone   may         mon       261         1    999         0
# 1  telephone   may         mon       149         1    999         0
# 2  telephone   may         mon       226         1    999         0
# 3  telephone   may         mon       151         1    999         0
# 4  telephone   may         mon       307         1    999         0
# 5  telephone   may         mon       198         1    999         0
# 6  telephone   may         mon       139         1    999         0
# 7  telephone   may         mon       217         1    999         0
# 8  telephone   may         mon       380         1    999         0
# 9  telephone   may         mon        50         1    999         0
#
#       poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0  nonexistent           1.1          93.994          -36.4      4.857
# 1  nonexistent           1.1          93.994          -36.4      4.857
# 2  nonexistent           1.1          93.994          -36.4      4.857
# 3  nonexistent           1.1          93.994          -36.4      4.857
# 4  nonexistent           1.1          93.994          -36.4      4.857
# 5  nonexistent           1.1          93.994          -36.4      4.857
# 6  nonexistent           1.1          93.994          -36.4      4.857
# 7  nonexistent           1.1          93.994          -36.4      4.857
# 8  nonexistent           1.1          93.994          -36.4      4.857
# 9  nonexistent           1.1          93.994          -36.4      4.857
#
#    nr.employed   y
# 0       5191.0  no
# 1       5191.0  no
# 2       5191.0  no
# 3       5191.0  no
# 4       5191.0  no
# 5       5191.0  no
# 6       5191.0  no
# 7       5191.0  no
# 8       5191.0  no
# 9       5191.0  no

# %%
data.shape # (number of lines, number of columns)
# Out:
# (41188, 21)

# %% [markdown]
# ## Splitting the dataset
#
# We split the dataset into training (95%) and test (5%) datasets. We will use the training dataset for AutoML, where it will be automatically split again for training and validation.
#
# Once the model has been deployed, we'll use the test dataset to evaluate its performance.

# %%
# Set the seed to 123 for reproductibility
# https://pandas.pydata.org/pandas-docs/version/0.25/generated/pandas.DataFrame.sample.html
# https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.split.html
train_data, test_data, _ = np.split(data.sample(frac=1, random_state=123), 
                                                  [int(0.95 * len(data)), int(len(data))])  

# Save to CSV files
train_data.to_csv('automl-train.csv', index=False, header=True, sep=',') # Need to keep column names
test_data.to_csv('automl-test.csv', index=False, header=True, sep=',')

# %%
# !ls -l automl*.csv
# Out:
# -rw-rw-r-- 1 ec2-user ec2-user  257339 Dec  9 04:33 automl-test.csv
# -rw-rw-r-- 1 ec2-user ec2-user 4889516 Dec  9 04:33 automl-train.csv

# %% [markdown]
# **No preprocessing needed!** AutoML will take care of this, so let's just copy the training set to S3.

# %%
sess.upload_data(path="automl-train.csv", key_prefix=prefix + "/input")
# Out:
# 's3://sagemaker-us-west-2-453691756499/sagemaker/DEMO-automl-dm/input/automl-train.csv'

# %% [markdown]
# ## Setting up the Amazon SageMaker AutoPilot job
#
# After uploading the dataset to S3, we can invoke SageMaker AutoPilot to find the best ML pipeline to train a model on this dataset.
#
# The required inputs for invoking a SageMaker AutoML job are the dataset location in S3, the name of the column of the dataset you want to predict (`y` in this case) and an IAM role.

# %%
job_config = {
    'CompletionCriteria': {
      'MaxRuntimePerTrainingJobInSeconds': 600,
      'MaxCandidates': 10,
      'MaxAutoMLJobRuntimeInSeconds': 3600
    },
}

input_data_config = [{
      'DataSource': {
        'S3DataSource': {
          'S3DataType': 'S3Prefix',
          'S3Uri': 's3://{}/{}/input'.format(bucket,prefix)
        }
      },
      'TargetAttributeName': 'y'  # the column we want to predict
    }
]

output_data_config = {
    'S3OutputPath': 's3://{}/{}/output'.format(bucket,prefix)
}

# %% [markdown]
# ## Launching the Amazon SageMaker AutoPilot job
#
# We can now launch the job by calling the `create_auto_ml_job` API.

# %%
from time import gmtime, strftime, sleep
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())

auto_ml_job_name = 'automl-dm-' + timestamp_suffix
print('AutoMLJobName: ' + auto_ml_job_name)

sm.create_auto_ml_job(AutoMLJobName=auto_ml_job_name,
                      InputDataConfig=input_data_config,
                      OutputDataConfig=output_data_config,
                      AutoMLJobConfig=job_config,
                      RoleArn=role)
# Out:
# AutoMLJobName: automl-dm-09-04-34-29
# {'AutoMLJobArn': 'arn:aws:sagemaker:us-west-2:453691756499:automl-job/automl-dm-09-04-34-29',
#  'ResponseMetadata': {'RequestId': '1adaa2fe-156e-4468-b108-a03de17b2ba2',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '1adaa2fe-156e-4468-b108-a03de17b2ba2',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '92',
#    'date': 'Mon, 09 Dec 2019 04:34:29 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Tracking the progress of the Amazon SageMaker AutoPilot job
# SageMaker AutoPilot job consists of four high-level steps :
# * Data Preprocessing, where the dataset is split into train and validation sets.
# * Recommending Pipelines, where the dataset is analyzed and SageMaker AutoPilot comes up with a list of ML pipelines that should be tried out on the dataset.
# * Automatic Feature Engineering, where SageMaker AutoPilot performs feature transformation on individual features of the dataset as well as at an aggregate level.
# * ML pipeline selection and hyperparameter tuning, where the top performing pipeline is selected along with the optimal hyperparameters for the training algorithm (the last stage of the pipeline).
#
# As you can guess, several of these steps are powered by **Amazon SageMaker Processing**.

# %%
# %%time
job_run_status = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['AutoMLJobStatus']

print(job_run_status)

while job_run_status not in ('Failed', 'Completed', 'Stopped'):
    describe_response = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
    job_run_status = describe_response['AutoMLJobStatus']
    
    print (describe_response['AutoMLJobStatus'] + " - " + describe_response['AutoMLJobSecondaryStatus'])
    sleep(60)
# Out:
# InProgress
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - AnalyzingData
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - FeatureEngineering
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# InProgress - ModelTuning
# Completed - MaxCandidatesReached
# CPU times: user 413 ms, sys: 10.8 ms, total: 424 ms
# Wall time: 29min 4s

# %% [markdown]
# ### Inspecting the SageMaker Autopilot job with Amazon SageMaker Experiments

# %%
from sagemaker.analytics import ExperimentAnalytics

analytics = ExperimentAnalytics(
    sagemaker_session=sess, 
    experiment_name=auto_ml_job_name+'-aws-auto-ml-job'
)

df = analytics.dataframe()
df
# Out:
#                                    TrialComponentName  \
# 0   automl-dm-09-tuning-job-1-3a268-009-6c889f29-a...
# 1   automl-dm-09-tuning-job-1-3a268-007-c1ae9a71-a...
# 2   automl-dm-09-tuning-job-1-3a268-006-057361d1-a...
# 3   automl-dm-09-tuning-job-1-3a268-005-1ab5f8a3-a...
# 4   automl-dm-09-tuning-job-1-3a268-008-e26ef964-a...
# 5   automl-dm-09-tuning-job-1-3a268-003-ed833680-a...
# 6   automl-dm-09-tuning-job-1-3a268-010-94204782-a...
# 7   automl-dm-09-tuning-job-1-3a268-001-f7db5792-a...
# 8   automl-dm-09-tuning-job-1-3a268-002-8aa752d3-a...
# 9   automl-dm-09-tuning-job-1-3a268-004-5a614c2a-a...
# 10  automl-dm-09-04-34-29-automl-dm--dpp8-csv-1-4a...
# 11  automl-dm-09-04-34-29-automl-dm--dpp7-rpb-1-fc...
# 12  automl-dm-09-04-34-29-automl-dm--dpp5-rpb-1-b0...
# 13  automl-dm-09-04-34-29-automl-dm--dpp8-1-c851bd...
# 14  automl-dm-09-04-34-29-automl-dm--dpp7-1-ce82f0...
# 15  automl-dm-09-04-34-29-automl-dm--dpp5-1-214960...
# 16  automl-dm-09-04-34-29-automl-dm--dpp2-rpb-1-2e...
# 17  automl-dm-09-04-34-29-automl-dm--dpp3-csv-1-4b...
# 18  automl-dm-09-04-34-29-automl-dm--dpp0-csv-1-92...
# 19  automl-dm-09-04-34-29-automl-dm--dpp1-csv-1-b6...
# 20  automl-dm-09-04-34-29-automl-dm--dpp2-1-ed9812...
# 21  automl-dm-09-04-34-29-automl-dm--dpp3-1-2ae21c...
# 22  automl-dm-09-04-34-29-automl-dm--dpp0-1-2a614a...
# 23  automl-dm-09-04-34-29-automl-dm--dpp1-1-afb8db...
# 24  automl-dm-09-04-34-29-db-1-ba401741abc04901981...
#
#                                           DisplayName  \
# 0   automl-dm-09-tuning-job-1-3a268-009-6c889f29-a...
# 1   automl-dm-09-tuning-job-1-3a268-007-c1ae9a71-a...
# 2   automl-dm-09-tuning-job-1-3a268-006-057361d1-a...
# 3   automl-dm-09-tuning-job-1-3a268-005-1ab5f8a3-a...
# 4   automl-dm-09-tuning-job-1-3a268-008-e26ef964-a...
# 5   automl-dm-09-tuning-job-1-3a268-003-ed833680-a...
# 6   automl-dm-09-tuning-job-1-3a268-010-94204782-a...
# 7   automl-dm-09-tuning-job-1-3a268-001-f7db5792-a...
# 8   automl-dm-09-tuning-job-1-3a268-002-8aa752d3-a...
# 9   automl-dm-09-tuning-job-1-3a268-004-5a614c2a-a...
# 10  automl-dm-09-04-34-29-automl-dm--dpp8-csv-1-4a...
# 11  automl-dm-09-04-34-29-automl-dm--dpp7-rpb-1-fc...
# 12  automl-dm-09-04-34-29-automl-dm--dpp5-rpb-1-b0...
# 13  automl-dm-09-04-34-29-automl-dm--dpp8-1-c851bd...
# 14  automl-dm-09-04-34-29-automl-dm--dpp7-1-ce82f0...
# 15  automl-dm-09-04-34-29-automl-dm--dpp5-1-214960...
# 16  automl-dm-09-04-34-29-automl-dm--dpp2-rpb-1-2e...
# 17  automl-dm-09-04-34-29-automl-dm--dpp3-csv-1-4b...
# 18  automl-dm-09-04-34-29-automl-dm--dpp0-csv-1-92...
# 19  automl-dm-09-04-34-29-automl-dm--dpp1-csv-1-b6...
# 20  automl-dm-09-04-34-29-automl-dm--dpp2-1-ed9812...
# 21  automl-dm-09-04-34-29-automl-dm--dpp3-1-2ae21c...
# 22  automl-dm-09-04-34-29-automl-dm--dpp0-1-2a614a...
# 23  automl-dm-09-04-34-29-automl-dm--dpp1-1-afb8db...
# 24  automl-dm-09-04-34-29-db-1-ba401741abc04901981...
#
#                                             SourceArn  \
# 0   arn:aws:sagemaker:us-west-2:453691756499:train...
# 1   arn:aws:sagemaker:us-west-2:453691756499:train...
# 2   arn:aws:sagemaker:us-west-2:453691756499:train...
# 3   arn:aws:sagemaker:us-west-2:453691756499:train...
# 4   arn:aws:sagemaker:us-west-2:453691756499:train...
# 5   arn:aws:sagemaker:us-west-2:453691756499:train...
# 6   arn:aws:sagemaker:us-west-2:453691756499:train...
# 7   arn:aws:sagemaker:us-west-2:453691756499:train...
# 8   arn:aws:sagemaker:us-west-2:453691756499:train...
# 9   arn:aws:sagemaker:us-west-2:453691756499:train...
# 10  arn:aws:sagemaker:us-west-2:453691756499:trans...
# 11  arn:aws:sagemaker:us-west-2:453691756499:trans...
# 12  arn:aws:sagemaker:us-west-2:453691756499:trans...
# 13  arn:aws:sagemaker:us-west-2:453691756499:train...
# 14  arn:aws:sagemaker:us-west-2:453691756499:train...
# 15  arn:aws:sagemaker:us-west-2:453691756499:train...
# 16  arn:aws:sagemaker:us-west-2:453691756499:trans...
# 17  arn:aws:sagemaker:us-west-2:453691756499:trans...
# 18  arn:aws:sagemaker:us-west-2:453691756499:trans...
# 19  arn:aws:sagemaker:us-west-2:453691756499:trans...
# 20  arn:aws:sagemaker:us-west-2:453691756499:train...
# 21  arn:aws:sagemaker:us-west-2:453691756499:train...
# 22  arn:aws:sagemaker:us-west-2:453691756499:train...
# 23  arn:aws:sagemaker:us-west-2:453691756499:train...
# 24  arn:aws:sagemaker:us-west-2:453691756499:proce...
#
#                                    SageMaker.ImageUri  \
# 0   246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 1   246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 2   246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 3   246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 4   246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 5   246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 6   174872318107.dkr.ecr.us-west-2.amazonaws.com/l...
# 7   246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 8   246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 9   246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 14  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 15  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 21  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 22  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 23  246618743249.dkr.ecr.us-west-2.amazonaws.com/s...
# 24                                                NaN
#
#     SageMaker.InstanceCount SageMaker.InstanceType  SageMaker.VolumeSizeInGB  \
# 0                       1.0          ml.m5.4xlarge                      50.0
# 1                       1.0          ml.m5.4xlarge                      50.0
# 2                       1.0          ml.m5.4xlarge                      50.0
# 3                       1.0          ml.m5.4xlarge                      50.0
# 4                       1.0          ml.m5.4xlarge                      50.0
# 5                       1.0          ml.m5.4xlarge                      50.0
# 6                       1.0          ml.m5.4xlarge                      50.0
# 7                       1.0          ml.m5.4xlarge                      50.0
# 8                       1.0          ml.m5.4xlarge                      50.0
# 9                       1.0          ml.m5.4xlarge                      50.0
# 10                      1.0          ml.m5.4xlarge                       NaN
# 11                      1.0          ml.m5.4xlarge                       NaN
# 12                      1.0          ml.m5.4xlarge                       NaN
# 13                      1.0          ml.m5.4xlarge                      50.0
# 14                      1.0          ml.m5.4xlarge                      50.0
# 15                      1.0          ml.m5.4xlarge                      50.0
# 16                      1.0          ml.m5.4xlarge                       NaN
# 17                      1.0          ml.m5.4xlarge                       NaN
# 18                      1.0          ml.m5.4xlarge                       NaN
# 19                      1.0          ml.m5.4xlarge                       NaN
# 20                      1.0          ml.m5.4xlarge                      50.0
# 21                      1.0          ml.m5.4xlarge                      50.0
# 22                      1.0          ml.m5.4xlarge                      50.0
# 23                      1.0          ml.m5.4xlarge                      50.0
# 24                      1.0          ml.m5.2xlarge                     250.0
#
#                      _tuning_objective_metric     alpha  colsample_bytree  \
# 0                         validation:accuracy  0.000003          0.676956
# 1                         validation:accuracy  0.000003          0.676956
# 2                         validation:accuracy  0.000003          0.676956
# 3                         validation:accuracy  0.000003          0.676956
# 4                         validation:accuracy  0.000003          0.676956
# 5                         validation:accuracy  0.000016          0.393186
# 6   validation:binary_classification_accuracy       NaN               NaN
# 7                         validation:accuracy  0.000016          0.393186
# 8                         validation:accuracy  0.000016          0.393186
# 9                         validation:accuracy  0.000003          0.676956
# 10                                        NaN       NaN               NaN
# 11                                        NaN       NaN               NaN
# 12                                        NaN       NaN               NaN
# 13                                        NaN       NaN               NaN
# 14                                        NaN       NaN               NaN
# 15                                        NaN       NaN               NaN
# 16                                        NaN       NaN               NaN
# 17                                        NaN       NaN               NaN
# 18                                        NaN       NaN               NaN
# 19                                        NaN       NaN               NaN
# 20                                        NaN       NaN               NaN
# 21                                        NaN       NaN               NaN
# 22                                        NaN       NaN               NaN
# 23                                        NaN       NaN               NaN
# 24                                        NaN       NaN               NaN
#
#          eta     gamma    lambda  max_depth  min_child_weight  num_round  \
# 0   0.001582  0.006241  0.000078        3.0          0.012706      270.0
# 1   0.001582  0.006241  0.000078        3.0          0.012706      270.0
# 2   0.001582  0.006241  0.000078        3.0          0.012706      270.0
# 3   0.001582  0.006241  0.000078        3.0          0.012706      270.0
# 4   0.001582  0.006241  0.000078        3.0          0.012706      270.0
# 5   0.025153  0.000119  0.000027       30.0          0.035558      187.0
# 6        NaN       NaN       NaN        NaN               NaN        NaN
# 7   0.025153  0.000119  0.000027       30.0          0.035558      187.0
# 8   0.025153  0.000119  0.000027       30.0          0.035558      187.0
# 9   0.001582  0.006241  0.000078        3.0          0.012706      270.0
# 10       NaN       NaN       NaN        NaN               NaN        NaN
# 11       NaN       NaN       NaN        NaN               NaN        NaN
# 12       NaN       NaN       NaN        NaN               NaN        NaN
# 13       NaN       NaN       NaN        NaN               NaN        NaN
# 14       NaN       NaN       NaN        NaN               NaN        NaN
# 15       NaN       NaN       NaN        NaN               NaN        NaN
# 16       NaN       NaN       NaN        NaN               NaN        NaN
# 17       NaN       NaN       NaN        NaN               NaN        NaN
# 18       NaN       NaN       NaN        NaN               NaN        NaN
# 19       NaN       NaN       NaN        NaN               NaN        NaN
# 20       NaN       NaN       NaN        NaN               NaN        NaN
# 21       NaN       NaN       NaN        NaN               NaN        NaN
# 22       NaN       NaN       NaN        NaN               NaN        NaN
# 23       NaN       NaN       NaN        NaN               NaN        NaN
# 24       NaN       NaN       NaN        NaN               NaN        NaN
#
#        objective  subsample  ObjectiveMetric - Min  ObjectiveMetric - Max  \
# 0   binary:hinge   0.832690                    NaN                    NaN
# 1   binary:hinge   0.832690               0.112588               0.112588
# 2   binary:hinge   0.832690                    NaN                    NaN
# 3   binary:hinge   0.832690                    NaN                    NaN
# 4   binary:hinge   0.832690                    NaN                    NaN
# 5   binary:hinge   0.660072                    NaN                    NaN
# 6            NaN        NaN                    NaN                    NaN
# 7   binary:hinge   0.660072                    NaN                    NaN
# 8   binary:hinge   0.660072                    NaN                    NaN
# 9   binary:hinge   0.832690               0.112588               0.112588
# 10           NaN        NaN                    NaN                    NaN
# 11           NaN        NaN                    NaN                    NaN
# 12           NaN        NaN                    NaN                    NaN
# 13           NaN        NaN                    NaN                    NaN
# 14           NaN        NaN                    NaN                    NaN
# 15           NaN        NaN                    NaN                    NaN
# 16           NaN        NaN                    NaN                    NaN
# 17           NaN        NaN                    NaN                    NaN
# 18           NaN        NaN                    NaN                    NaN
# 19           NaN        NaN                    NaN                    NaN
# 20           NaN        NaN                    NaN                    NaN
# 21           NaN        NaN                    NaN                    NaN
# 22           NaN        NaN                    NaN                    NaN
# 23           NaN        NaN                    NaN                    NaN
# 24           NaN        NaN                    NaN                    NaN
#
#     ObjectiveMetric - Avg  ObjectiveMetric - StdDev  ObjectiveMetric - Last  \
# 0                     NaN                       NaN                     NaN
# 1                0.112588                       0.0                0.112588
# 2                     NaN                       NaN                     NaN
# 3                     NaN                       NaN                     NaN
# 4                     NaN                       NaN                     NaN
# 5                     NaN                       NaN                     NaN
# 6                     NaN                       NaN                     NaN
# 7                     NaN                       NaN                     NaN
# 8                     NaN                       NaN                     NaN
# 9                0.112588                       0.0                0.112588
# 10                    NaN                       NaN                     NaN
# 11                    NaN                       NaN                     NaN
# 12                    NaN                       NaN                     NaN
# 13                    NaN                       NaN                     NaN
# 14                    NaN                       NaN                     NaN
# 15                    NaN                       NaN                     NaN
# 16                    NaN                       NaN                     NaN
# 17                    NaN                       NaN                     NaN
# 18                    NaN                       NaN                     NaN
# 19                    NaN                       NaN                     NaN
# 20                    NaN                       NaN                     NaN
# 21                    NaN                       NaN                     NaN
# 22                    NaN                       NaN                     NaN
# 23                    NaN                       NaN                     NaN
# 24                    NaN                       NaN                     NaN
#
#     ObjectiveMetric - Count  validation:error - Min  validation:error - Max  \
# 0                       NaN                     NaN                     NaN
# 1                      43.0                0.887412                0.887412
# 2                       NaN                     NaN                     NaN
# 3                       NaN                     NaN                     NaN
# 4                       NaN                     NaN                     NaN
# 5                       NaN                     NaN                     NaN
# 6                       NaN                     NaN                     NaN
# 7                       NaN                     NaN                     NaN
# 8                       NaN                     NaN                     NaN
# 9                      44.0                0.887412                0.887412
# 10                      NaN                     NaN                     NaN
# 11                      NaN                     NaN                     NaN
# 12                      NaN                     NaN                     NaN
# 13                      NaN                     NaN                     NaN
# 14                      NaN                     NaN                     NaN
# 15                      NaN                     NaN                     NaN
# 16                      NaN                     NaN                     NaN
# 17                      NaN                     NaN                     NaN
# 18                      NaN                     NaN                     NaN
# 19                      NaN                     NaN                     NaN
# 20                      NaN                     NaN                     NaN
# 21                      NaN                     NaN                     NaN
# 22                      NaN                     NaN                     NaN
# 23                      NaN                     NaN                     NaN
# 24                      NaN                     NaN                     NaN
#
#     validation:error - Avg  validation:error - StdDev  \
# 0                      NaN                        NaN
# 1                 0.887412                        0.0
# 2                      NaN                        NaN
# 3                      NaN                        NaN
# 4                      NaN                        NaN
# 5                      NaN                        NaN
# 6                      NaN                        NaN
# 7                      NaN                        NaN
# 8                      NaN                        NaN
# 9                 0.887412                        0.0
# 10                     NaN                        NaN
# 11                     NaN                        NaN
# 12                     NaN                        NaN
# 13                     NaN                        NaN
# 14                     NaN                        NaN
# 15                     NaN                        NaN
# 16                     NaN                        NaN
# 17                     NaN                        NaN
# 18                     NaN                        NaN
# 19                     NaN                        NaN
# 20                     NaN                        NaN
# 21                     NaN                        NaN
# 22                     NaN                        NaN
# 23                     NaN                        NaN
# 24                     NaN                        NaN
#
#     validation:error - Last  validation:error - Count  \
# 0                       NaN                       NaN
# 1                  0.887412                      43.0
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
# 5                       NaN                       NaN
# 6                       NaN                       NaN
# 7                       NaN                       NaN
# 8                       NaN                       NaN
# 9                  0.887412                      44.0
# 10                      NaN                       NaN
# 11                      NaN                       NaN
# 12                      NaN                       NaN
# 13                      NaN                       NaN
# 14                      NaN                       NaN
# 15                      NaN                       NaN
# 16                      NaN                       NaN
# 17                      NaN                       NaN
# 18                      NaN                       NaN
# 19                      NaN                       NaN
# 20                      NaN                       NaN
# 21                      NaN                       NaN
# 22                      NaN                       NaN
# 23                      NaN                       NaN
# 24                      NaN                       NaN
#
#     validation:accuracy - Min  validation:accuracy - Max  \
# 0                         NaN                        NaN
# 1                    0.112588                   0.112588
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# 7                         NaN                        NaN
# 8                         NaN                        NaN
# 9                    0.112588                   0.112588
# 10                        NaN                        NaN
# 11                        NaN                        NaN
# 12                        NaN                        NaN
# 13                        NaN                        NaN
# 14                        NaN                        NaN
# 15                        NaN                        NaN
# 16                        NaN                        NaN
# 17                        NaN                        NaN
# 18                        NaN                        NaN
# 19                        NaN                        NaN
# 20                        NaN                        NaN
# 21                        NaN                        NaN
# 22                        NaN                        NaN
# 23                        NaN                        NaN
# 24                        NaN                        NaN
#
#     validation:accuracy - Avg  validation:accuracy - StdDev  \
# 0                         NaN                           NaN
# 1                    0.112588                           0.0
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# 5                         NaN                           NaN
# 6                         NaN                           NaN
# 7                         NaN                           NaN
# 8                         NaN                           NaN
# 9                    0.112588                           0.0
# 10                        NaN                           NaN
# 11                        NaN                           NaN
# 12                        NaN                           NaN
# 13                        NaN                           NaN
# 14                        NaN                           NaN
# 15                        NaN                           NaN
# 16                        NaN                           NaN
# 17                        NaN                           NaN
# 18                        NaN                           NaN
# 19                        NaN                           NaN
# 20                        NaN                           NaN
# 21                        NaN                           NaN
# 22                        NaN                           NaN
# 23                        NaN                           NaN
# 24                        NaN                           NaN
#
#     validation:accuracy - Last  validation:accuracy - Count  \
# 0                          NaN                          NaN
# 1                     0.112588                         43.0
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                          NaN                          NaN
# 6                          NaN                          NaN
# 7                          NaN                          NaN
# 8                          NaN                          NaN
# 9                     0.112588                         44.0
# 10                         NaN                          NaN
# 11                         NaN                          NaN
# 12                         NaN                          NaN
# 13                         NaN                          NaN
# 14                         NaN                          NaN
# 15                         NaN                          NaN
# 16                         NaN                          NaN
# 17                         NaN                          NaN
# 18                         NaN                          NaN
# 19                         NaN                          NaN
# 20                         NaN                          NaN
# 21                         NaN                          NaN
# 22                         NaN                          NaN
# 23                         NaN                          NaN
# 24                         NaN                          NaN
#
#     train:error - Min  train:error - Max  train:error - Avg  \
# 0                 NaN                NaN                NaN
# 1            0.887519           0.887519           0.887519
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9            0.887519           0.887519           0.887519
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 24                NaN                NaN                NaN
#
#     train:error - StdDev  train:error - Last  train:error - Count  \
# 0                    NaN                 NaN                  NaN
# 1                    0.0            0.887519                 43.0
# 2                    NaN                 NaN                  NaN
# 3                    NaN                 NaN                  NaN
# 4                    NaN                 NaN                  NaN
# 5                    NaN                 NaN                  NaN
# 6                    NaN                 NaN                  NaN
# 7                    NaN                 NaN                  NaN
# 8                    NaN                 NaN                  NaN
# 9                    0.0            0.887519                 44.0
# 10                   NaN                 NaN                  NaN
# 11                   NaN                 NaN                  NaN
# 12                   NaN                 NaN                  NaN
# 13                   NaN                 NaN                  NaN
# 14                   NaN                 NaN                  NaN
# 15                   NaN                 NaN                  NaN
# 16                   NaN                 NaN                  NaN
# 17                   NaN                 NaN                  NaN
# 18                   NaN                 NaN                  NaN
# 19                   NaN                 NaN                  NaN
# 20                   NaN                 NaN                  NaN
# 21                   NaN                 NaN                  NaN
# 22                   NaN                 NaN                  NaN
# 23                   NaN                 NaN                  NaN
# 24                   NaN                 NaN                  NaN
#
#     train:accuracy - Min  train:accuracy - Max  train:accuracy - Avg  \
# 0                    NaN                   NaN                   NaN
# 1               0.112481              0.112481              0.112481
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
# 5                    NaN                   NaN                   NaN
# 6                    NaN                   NaN                   NaN
# 7                    NaN                   NaN                   NaN
# 8                    NaN                   NaN                   NaN
# 9               0.112481              0.112481              0.112481
# 10                   NaN                   NaN                   NaN
# 11                   NaN                   NaN                   NaN
# 12                   NaN                   NaN                   NaN
# 13                   NaN                   NaN                   NaN
# 14                   NaN                   NaN                   NaN
# 15                   NaN                   NaN                   NaN
# 16                   NaN                   NaN                   NaN
# 17                   NaN                   NaN                   NaN
# 18                   NaN                   NaN                   NaN
# 19                   NaN                   NaN                   NaN
# 20                   NaN                   NaN                   NaN
# 21                   NaN                   NaN                   NaN
# 22                   NaN                   NaN                   NaN
# 23                   NaN                   NaN                   NaN
# 24                   NaN                   NaN                   NaN
#
#     train:accuracy - StdDev  train:accuracy - Last  train:accuracy - Count  \
# 0                       NaN                    NaN                     NaN
# 1                       0.0               0.112481                    43.0
# 2                       NaN                    NaN                     NaN
# 3                       NaN                    NaN                     NaN
# 4                       NaN                    NaN                     NaN
# 5                       NaN                    NaN                     NaN
# 6                       NaN                    NaN                     NaN
# 7                       NaN                    NaN                     NaN
# 8                       NaN                    NaN                     NaN
# 9                       0.0               0.112481                    44.0
# 10                      NaN                    NaN                     NaN
# 11                      NaN                    NaN                     NaN
# 12                      NaN                    NaN                     NaN
# 13                      NaN                    NaN                     NaN
# 14                      NaN                    NaN                     NaN
# 15                      NaN                    NaN                     NaN
# 16                      NaN                    NaN                     NaN
# 17                      NaN                    NaN                     NaN
# 18                      NaN                    NaN                     NaN
# 19                      NaN                    NaN                     NaN
# 20                      NaN                    NaN                     NaN
# 21                      NaN                    NaN                     NaN
# 22                      NaN                    NaN                     NaN
# 23                      NaN                    NaN                     NaN
# 24                      NaN                    NaN                     NaN
#
#    binary_classifier_model_selection_criteria            l1  learning_rate  \
# 0                                         NaN           NaN            NaN
# 1                                         NaN           NaN            NaN
# 2                                         NaN           NaN            NaN
# 3                                         NaN           NaN            NaN
# 4                                         NaN           NaN            NaN
# 5                                         NaN           NaN            NaN
# 6                               loss_function  2.801905e-07       0.004927
# 7                                         NaN           NaN            NaN
# 8                                         NaN           NaN            NaN
# 9                                         NaN           NaN            NaN
# 10                                        NaN           NaN            NaN
# 11                                        NaN           NaN            NaN
# 12                                        NaN           NaN            NaN
# 13                                        NaN           NaN            NaN
# 14                                        NaN           NaN            NaN
# 15                                        NaN           NaN            NaN
# 16                                        NaN           NaN            NaN
# 17                                        NaN           NaN            NaN
# 18                                        NaN           NaN            NaN
# 19                                        NaN           NaN            NaN
# 20                                        NaN           NaN            NaN
# 21                                        NaN           NaN            NaN
# 22                                        NaN           NaN            NaN
# 23                                        NaN           NaN            NaN
# 24                                        NaN           NaN            NaN
#
#         loss  mini_batch_size  num_models  positive_example_weight_mult  \
# 0        NaN              NaN         NaN                           NaN
# 1        NaN              NaN         NaN                           NaN
# 2        NaN              NaN         NaN                           NaN
# 3        NaN              NaN         NaN                           NaN
# 4        NaN              NaN         NaN                           NaN
# 5        NaN              NaN         NaN                           NaN
# 6   logistic           1000.0         1.0                          0.01
# 7        NaN              NaN         NaN                           NaN
# 8        NaN              NaN         NaN                           NaN
# 9        NaN              NaN         NaN                           NaN
# 10       NaN              NaN         NaN                           NaN
# 11       NaN              NaN         NaN                           NaN
# 12       NaN              NaN         NaN                           NaN
# 13       NaN              NaN         NaN                           NaN
# 14       NaN              NaN         NaN                           NaN
# 15       NaN              NaN         NaN                           NaN
# 16       NaN              NaN         NaN                           NaN
# 17       NaN              NaN         NaN                           NaN
# 18       NaN              NaN         NaN                           NaN
# 19       NaN              NaN         NaN                           NaN
# 20       NaN              NaN         NaN                           NaN
# 21       NaN              NaN         NaN                           NaN
# 22       NaN              NaN         NaN                           NaN
# 23       NaN              NaN         NaN                           NaN
# 24       NaN              NaN         NaN                           NaN
#
#        predictor_type        wd                processor_module  \
# 0                 NaN       NaN                             NaN
# 1                 NaN       NaN                             NaN
# 2                 NaN       NaN                             NaN
# 3                 NaN       NaN                             NaN
# 4                 NaN       NaN                             NaN
# 5                 NaN       NaN                             NaN
# 6   binary_classifier  0.000253                             NaN
# 7                 NaN       NaN                             NaN
# 8                 NaN       NaN                             NaN
# 9                 NaN       NaN                             NaN
# 10                NaN       NaN                             NaN
# 11                NaN       NaN                             NaN
# 12                NaN       NaN                             NaN
# 13                NaN       NaN  candidate_data_processors.dpp8
# 14                NaN       NaN  candidate_data_processors.dpp7
# 15                NaN       NaN  candidate_data_processors.dpp5
# 16                NaN       NaN                             NaN
# 17                NaN       NaN                             NaN
# 18                NaN       NaN                             NaN
# 19                NaN       NaN                             NaN
# 20                NaN       NaN  candidate_data_processors.dpp2
# 21                NaN       NaN  candidate_data_processors.dpp3
# 22                NaN       NaN  candidate_data_processors.dpp0
# 23                NaN       NaN  candidate_data_processors.dpp1
# 24                NaN       NaN                             NaN
#
#                     sagemaker_program sagemaker_submit_directory  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# 2                                 NaN                        NaN
# 3                                 NaN                        NaN
# 4                                 NaN                        NaN
# 5                                 NaN                        NaN
# 6                                 NaN                        NaN
# 7                                 NaN                        NaN
# 8                                 NaN                        NaN
# 9                                 NaN                        NaN
# 10                                NaN                        NaN
# 11                                NaN                        NaN
# 12                                NaN                        NaN
# 13  candidate_data_processors.trainer    /opt/ml/input/data/code
# 14  candidate_data_processors.trainer    /opt/ml/input/data/code
# 15  candidate_data_processors.trainer    /opt/ml/input/data/code
# 16                                NaN                        NaN
# 17                                NaN                        NaN
# 18                                NaN                        NaN
# 19                                NaN                        NaN
# 20  candidate_data_processors.trainer    /opt/ml/input/data/code
# 21  candidate_data_processors.trainer    /opt/ml/input/data/code
# 22  candidate_data_processors.trainer    /opt/ml/input/data/code
# 23  candidate_data_processors.trainer    /opt/ml/input/data/code
# 24                                NaN                        NaN
#
#    input_channel_mode               job_name label_col
# 0                 NaN                    NaN       NaN
# 1                 NaN                    NaN       NaN
# 2                 NaN                    NaN       NaN
# 3                 NaN                    NaN       NaN
# 4                 NaN                    NaN       NaN
# 5                 NaN                    NaN       NaN
# 6                 NaN                    NaN       NaN
# 7                 NaN                    NaN       NaN
# 8                 NaN                    NaN       NaN
# 9                 NaN                    NaN       NaN
# 10                NaN                    NaN       NaN
# 11                NaN                    NaN       NaN
# 12                NaN                    NaN       NaN
# 13                NaN                    NaN       NaN
# 14                NaN                    NaN       NaN
# 15                NaN                    NaN       NaN
# 16                NaN                    NaN       NaN
# 17                NaN                    NaN       NaN
# 18                NaN                    NaN       NaN
# 19                NaN                    NaN       NaN
# 20                NaN                    NaN       NaN
# 21                NaN                    NaN       NaN
# 22                NaN                    NaN       NaN
# 23                NaN                    NaN       NaN
# 24               Pipe  automl-dm-09-04-34-29         y

# %% [markdown]
# ### Listing all candidates explored by Amazon SageMaker AutoPilot
# You can view all the candidates (pipeline evaluations with different hyperparameter combinations) that were explored by AutoML and sort them by their final performance metric.

# %%
candidates = sm.list_candidates_for_auto_ml_job(AutoMLJobName=auto_ml_job_name, 
                                                SortBy='FinalObjectiveMetricValue')['Candidates']
index = 1
for candidate in candidates:
  print (str(index) + "  " 
         + candidate['CandidateName'] + "  " 
         + str(candidate['FinalAutoMLJobObjectiveMetric']['Value']))
  index += 1
# Out:
# 1  automl-dm-09-tuning-job-1-3a268-003-ed833680  0.9100319743156433
# 2  automl-dm-09-tuning-job-1-3a268-001-f7db5792  0.9095209836959839
# 3  automl-dm-09-tuning-job-1-3a268-002-8aa752d3  0.9088820219039917
# 4  automl-dm-09-tuning-job-1-3a268-010-94204782  0.8874121308326721
# 5  automl-dm-09-tuning-job-1-3a268-004-5a614c2a  0.11258800327777863
# 6  automl-dm-09-tuning-job-1-3a268-008-e26ef964  0.11258800327777863
# 7  automl-dm-09-tuning-job-1-3a268-006-057361d1  0.11258800327777863
# 8  automl-dm-09-tuning-job-1-3a268-007-c1ae9a71  0.11258800327777863
# 9  automl-dm-09-tuning-job-1-3a268-005-1ab5f8a3  0.11258800327777863
# 10  automl-dm-09-tuning-job-1-3a268-009-6c889f29  0.11258800327777863

# %%
best_candidate = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)['BestCandidate']
best_candidate_name = best_candidate['CandidateName']

print("Candidate name: " + best_candidate_name)
# Out:
# Candidate name: automl-dm-09-tuning-job-1-3a268-003-ed833680

# %% [markdown]
# We can also see the containers and models composing the Inference Pipeline.

# %%
for container in best_candidate['InferenceContainers']:
    print(container['Image'])
    print(container['ModelDataUrl'])
    print('-')
# Out:
# 246618743249.dkr.ecr.us-west-2.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3
# s3://sagemaker-us-west-2-453691756499/sagemaker/DEMO-automl-dm/output/automl-dm-09-04-34-29/data-processor-models/automl-dm-09-04-34-29-automl-dm--dpp0-1-2a614a10de4c4cc0b8ce7f1/output/model.tar.gz
# -
# 246618743249.dkr.ecr.us-west-2.amazonaws.com/sagemaker-xgboost:0.90-1-cpu-py3
# s3://sagemaker-us-west-2-453691756499/sagemaker/DEMO-automl-dm/output/automl-dm-09-04-34-29/tuning/automl-dm--dpp0-xgb/automl-dm-09-tuning-job-1-3a268-003-ed833680/output/model.tar.gz
# -
# 246618743249.dkr.ecr.us-west-2.amazonaws.com/sagemaker-sklearn-automl:0.1.0-cpu-py3
# s3://sagemaker-us-west-2-453691756499/sagemaker/DEMO-automl-dm/output/automl-dm-09-04-34-29/data-processor-models/automl-dm-09-04-34-29-automl-dm--dpp0-1-2a614a10de4c4cc0b8ce7f1/output/model.tar.gz
# -

# %% [markdown]
# ### Fetching the auto-generated notebooks

# %% [markdown]
# SageMaker AutoPilot also generates two notebooks:
# * Data exploration,
# * Candidate definition.

# %%
job = sm.describe_auto_ml_job(AutoMLJobName=auto_ml_job_name)
job_candidate_notebook = job['AutoMLJobArtifacts']['CandidateDefinitionNotebookLocation']
job_data_notebook = job['AutoMLJobArtifacts']['DataExplorationNotebookLocation']

print(job_candidate_notebook)
print(job_data_notebook)
# Out:
# s3://sagemaker-us-west-2-453691756499/sagemaker/DEMO-automl-dm/output/automl-dm-09-04-34-29/sagemaker-automl-candidates/automl-dm-09-04-34-29-pr-1-17ddde359c11472192b705dff544e14f8626/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# s3://sagemaker-us-west-2-453691756499/sagemaker/DEMO-automl-dm/output/automl-dm-09-04-34-29/sagemaker-automl-candidates/automl-dm-09-04-34-29-pr-1-17ddde359c11472192b705dff544e14f8626/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# Let's copy these two notebooks.

# %%
# %%sh -s $job_candidate_notebook $job_data_notebook
# aws s3 cp $1 .
# aws s3 cp $2 .
# Out:
# download: s3://sagemaker-us-west-2-453691756499/sagemaker/DEMO-automl-dm/output/automl-dm-09-04-34-29/sagemaker-automl-candidates/automl-dm-09-04-34-29-pr-1-17ddde359c11472192b705dff544e14f8626/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb to ./SageMakerAutopilotCandidateDefinitionNotebook.ipynb
# download: s3://sagemaker-us-west-2-453691756499/sagemaker/DEMO-automl-dm/output/automl-dm-09-04-34-29/sagemaker-automl-candidates/automl-dm-09-04-34-29-pr-1-17ddde359c11472192b705dff544e14f8626/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb to ./SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# ## Deploying the best candidate, with Amazon SageMaker Model Monitor
# Now that we have successfully completed the AutoML job on our dataset and visualized the trials, we can create a model from any of the trials with a single API call and then deploy that model for online or batch prediction using [Inference Pipelines](https://docs.aws.amazon.com/sagemaker/latest/dg/inference-pipelines.html).

# %% [markdown]
# Let's create a SageMaker model for this Inference Pipeline.

# %%
model_name = 'automl-dm-model-' + timestamp_suffix

model_arn = sm.create_model(Containers=best_candidate['InferenceContainers'],
                            ModelName=model_name,
                            ExecutionRoleArn=role)

print('Model ARN: ', model_arn['ModelArn'])
# Out:
# Model ARN:  arn:aws:sagemaker:us-west-2:453691756499:model/automl-dm-model-09-04-34-29

# %% [markdown]
# Let's configure data capture.

# %%
s3_capture_path = 's3://reinvent-recap-demos/' + model_name + '/'

print(s3_capture_path)
# Out:
# s3://reinvent-recap-demos/automl-dm-model-09-04-34-29/

# %%
data_capture_configuration = {
    "EnableCapture": True, # flag turns data capture on and off
    "DestinationS3Uri": s3_capture_path, # s3 location where captured data is saved
    "InitialSamplingPercentage": 100, # sampling rate to capture data. max is 100%
    "CaptureOptions": [
       {
            "CaptureMode": "Output" # The type of capture this option enables. Values can be: [Output/Input]
        },
        {
            "CaptureMode": "Input" # The type of capture this option enables. Values can be: [Output/Input]
        }
    ],
    "CaptureContentTypeHeader": {
       "CsvContentTypes": ["text/csv"], # headers which should signal to decode the payload into CSV format 
       "JsonContentTypes": ["application/json"] # headers which should signal to decode the payload into JSON format 
    }
}

# %% [markdown]
# As usual, we first create the endpoint configuration, and then the endpoint.

# %%
# Endpoint configuration name
timestamp_suffix = strftime('%d-%H-%M-%S', gmtime())
epc_name = 'automl-dm-epc-' + timestamp_suffix
print('Endpoint configuration name:', epc_name)

ep_config = sm.create_endpoint_config(EndpointConfigName = epc_name,
                                      ProductionVariants=[{'InstanceType':'ml.m4.xlarge',
                                                           'InitialInstanceCount':1,
                                                           'ModelName':model_name,
                                                           'VariantName': 'AllTraffic'}],
                                      DataCaptureConfig = data_capture_configuration)
# Out:
# Endpoint configuration name: automl-dm-epc-09-05-26-23

# %%
# Endpoint name
ep_name = 'automl-dm-ep-' + timestamp_suffix
variant_name = 'automl-dm-variant-' + timestamp_suffix
print('Endpoint name:', ep_name)

create_endpoint_response = sm.create_endpoint(EndpointName=ep_name,
                                              EndpointConfigName=epc_name)
# Out:
# Endpoint name: automl-dm-ep-09-05-26-23

# %%
# %%time
sm.get_waiter('endpoint_in_service').wait(EndpointName=ep_name)

resp = sm.describe_endpoint(EndpointName=ep_name)
status = resp['EndpointStatus']

print("Endpoint ARN   : " + resp['EndpointArn'])
print("Endpoint status: " + status)
# Out:
# Endpoint ARN   : arn:aws:sagemaker:us-west-2:453691756499:endpoint/automl-dm-ep-09-05-26-23
# Endpoint status: InService
# CPU times: user 240 ms, sys: 9.02 ms, total: 249 ms
# Wall time: 9min 31s

# %% [markdown]
# ## Scoring the best candidate

# %% [markdown]
# Let's predict and score the test set. We'll compute metrics ourselves just for fun.

# %%
tp = tn = fp = fn = count = 0

with open('automl-test.csv') as f:
    lines = f.readlines()
    for l in lines[1:]:   # Skip header
        l = l.split(',')  # Split CSV line into features
        label = l[-1]     # Store 'yes'/'no' label
        l = l[:-1]        # Remove label
        l = ','.join(l)   # Rebuild CSV line without label
                
        response = sm_rt.invoke_endpoint(EndpointName=ep_name, ContentType='text/csv', Accept='text/csv', Body=l)

        response = response['Body'].read().decode("utf-8")
        #print ("label %s response %s" %(label,response))

        if 'yes' in label:
            # Sample is positive
            if 'yes' in response:
                # True positive
                tp=tp+1
            else:
                # False negative
                fn=fn+1
        else:
            # Sample is negative
            if 'no' in response:
                # True negative
                tn=tn+1
            else:
                # False positive
                fp=fp+1
        count = count+1
        if (count % 100 == 0):   
            sys.stdout.write(str(count)+' ')
            
print ("Done")
# Out:
# 100 200 300 400 500 600 700 800 900 1000 1100 1200 1300 1400 1500 1600 1700 1800 1900 2000 Done

# %%
# Confusion matrix
print ("%d %d" % (tn, fp))
print ("%d %d" % (fn, tp))

accuracy  = (tp+tn)/(tp+tn+fp+fn)
precision = tp/(tp+fp)
recall    = tn/(tn+fn)
f1        = (2*precision*recall)/(precision+recall)

print ("Accuracy: %.4f, Precision: %.4f, Recall: %.4f, F1: %.4f" % (accuracy, precision, recall, f1))
# Out:
# 1761 61
# 149 89
# Accuracy: 0.8981, Precision: 0.5933, Recall: 0.9220, F1: 0.7220

# %% [markdown]
# Let's check that we captured data.

# %%
# !aws s3 ls --recursive {s3_capture_path}
# Out:
# 2019-12-09 05:37:49     969830 automl-dm-model-09-04-34-29/automl-dm-ep-09-05-26-23/AllTraffic/2019/12/09/05/36-03-862-e7a0ce60-5843-49fb-aae8-c94862db161d.jsonl

# %%
# !aws s3 cp --recursive {s3_capture_path} .
# Out:
# download: s3://reinvent-recap-demos/automl-dm-model-09-04-34-29/automl-dm-ep-09-05-26-23/AllTraffic/2019/12/09/05/36-03-862-e7a0ce60-5843-49fb-aae8-c94862db161d.jsonl to automl-dm-ep-09-05-26-23/AllTraffic/2019/12/09/05/36-03-862-e7a0ce60-5843-49fb-aae8-c94862db161d.jsonl

# %%
# !head <file_name.jsonl>
# Out:
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"35,technician,single,professional.course,no,yes,no,cellular,aug,wed,156,2,999,0,nonexistent,1.4,93.444,-36.1,4.965,5228.1","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"1577c6d8-a2d8-4134-8577-e7bbb5661708","inferenceTime":"2019-12-09T05:36:03Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"43,blue-collar,single,basic.4y,unknown,yes,no,telephone,may,mon,225,1,999,0,nonexistent,1.1,93.994,-36.4,4.857,5191.0","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"5f127d44-e349-4820-a66d-8d0772ed932c","inferenceTime":"2019-12-09T05:36:04Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"48,blue-collar,married,basic.9y,unknown,yes,no,cellular,aug,thu,122,1,999,0,nonexistent,1.4,93.444,-36.1,4.968,5228.1","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"c3bcf7ef-73c0-456b-92fa-2141efe9d6d1","inferenceTime":"2019-12-09T05:36:04Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"42,technician,married,university.degree,unknown,yes,no,cellular,may,wed,301,1,999,0,nonexistent,-1.8,92.89299999999999,-46.2,1.334,5099.1","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"dfabcca1-7213-4f43-ad09-b099998e9ee9","inferenceTime":"2019-12-09T05:36:04Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"30,blue-collar,married,basic.9y,unknown,yes,no,cellular,may,wed,297,1,999,0,nonexistent,-1.8,92.89299999999999,-46.2,1.334,5099.1","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"c69c9981-6ff3-4f3b-b88c-4197fe9e371b","inferenceTime":"2019-12-09T05:36:04Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"32,technician,single,university.degree,no,yes,no,telephone,jun,tue,45,2,999,0,nonexistent,1.4,94.465,-41.8,4.961,5228.1","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"a2d9283d-c4fd-4f81-9937-794cbb085573","inferenceTime":"2019-12-09T05:36:04Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"46,blue-collar,married,unknown,no,no,yes,cellular,jul,thu,36,1,999,0,nonexistent,1.4,93.91799999999999,-42.7,4.962,5228.1","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"2eec079d-d9c5-4d73-a782-91821eee77bd","inferenceTime":"2019-12-09T05:36:04Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"29,admin.,single,university.degree,no,yes,yes,cellular,nov,fri,1222,2,999,0,nonexistent,-0.1,93.2,-42.0,4.021,5195.8","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"a0d70629-c54f-426e-900b-ce207fc87366","inferenceTime":"2019-12-09T05:36:04Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"24,blue-collar,single,basic.4y,no,yes,yes,cellular,jul,wed,132,1,999,0,nonexistent,1.4,93.91799999999999,-42.7,4.963,5228.1","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"3dc851d6-ebec-41d5-8ad7-2ab8461bd9a6","inferenceTime":"2019-12-09T05:36:04Z"},"eventVersion":"0"}
# {"captureData":{"endpointInput":{"observedContentType":"text/csv","mode":"INPUT","data":"23,entrepreneur,married,professional.course,no,no,no,cellular,jul,tue,58,1,999,0,nonexistent,1.4,93.91799999999999,-42.7,4.962,5228.1","encoding":"CSV"},"endpointOutput":{"observedContentType":"text/csv; charset=utf-8","mode":"OUTPUT","data":"no\n","encoding":"CSV"}},"eventMetadata":{"eventId":"b9cf4c5f-235c-4727-88f6-a910be74aa4a","inferenceTime":"2019-12-09T05:36:04Z"},"eventVersion":"0"}

# %% [markdown]
# ## Deleting the endpoint
# Once that we're done predicting, we can delete the endpoint (and stop paying for it).

# %%
# Uncomment to delete
sm.delete_endpoint(EndpointName=ep_name)
# Out:
# {'ResponseMetadata': {'RequestId': '511f7315-d60d-48bb-849c-aa89e58293ba',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '511f7315-d60d-48bb-849c-aa89e58293ba',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Mon, 09 Dec 2019 05:48:57 GMT'},
#   'RetryAttempts': 0}}
